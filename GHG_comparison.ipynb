# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
headers=pd.read_csv(r'data\rockcliff-20220706214209323-Header.csv')

# %%
loc=pd.read_csv(r'data\rockcliff-20220706214209323-WellLocation.csv')

# %%
headers['API_10']=headers['API'].astype(str).str[:10]

# %%
loc['API_10']=loc['API'].astype(str)

# %%
merged=pd.merge(headers,loc,on='API_10')

# %%
sns.scatterplot(data=merged,x='Longitude',y='Latitude',hue='SurfaceAddress1', legend=False)
#plt.legend(loc='lower right')
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
df.shape

# %%
pads.shape

# %%
df.head()
