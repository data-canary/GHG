# %%
from keplergl import KeplerGl

# %%
from shapely.wkt import loads

# %%
import pandas as pd

# %%
#import geopandas as gpd

# %%
#headers=pd.read_csv(r'data\rockcliff-20220706214209323-Header.csv')

# %%
prod=pd.read_csv(r'data\Rockcliff-20220707222136820-Production.csv')

# %%
headers['API_10']=headers['API'].astype(str).str[:10]

# %%
loc['API_10']=loc['API'].astype(str)

# %%
merged=pd.merge(headers,loc,on='API_10')

# %%
gdf = gpd.GeoDataFrame(merged, geometry=gpd.points_from_xy(merged.Longitude, merged.Latitude))

# %%
canaries_df=pd.read_csv(r'data\rockcliff_pc_devices.csv')

# %%
canaries=gpd.GeoDataFrame(data=canaries_df,geometry=gpd.points_from_xy(canaries_df.longitude, canaries_df.latitude))

# %%
#canaries.geometry=canaries['geometry'].apply(loads)

# %%
canaries=canaries.set_crs(3857)

# %%
gdf=gdf.set_crs(3857)

# %%
map_1=KeplerGl(height=500)
map_1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(height=500)

# %%
map_1.add_data(data=gdf, name="Wells")
# Out:
# c:\Code\envs\keplergl\lib\site-packages\jupyter_client\session.py:716: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#   content = self.pack(content)

# %%
map_1.add_data(data=canaries, name="canaries")
# Out:
# c:\Code\envs\keplergl\lib\site-packages\jupyter_client\session.py:716: UserWarning: Message serialization failed with:
# Out of range float values are not JSON compliant
# Supporting this message is deprecated in jupyter-client 7, please make sure your message is JSON-compliant
#   content = self.pack(content)
